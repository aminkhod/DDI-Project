# %%
import numpy as np
import pandas as pd

# %%
excel_file='drug_drug_matrix.csv'
drug=pd.read_csv(excel_file,header=None)
df='drug_list (1).csv'
DF=pd.read_csv(df,header=None)
d='drugs.csv'
D=pd.read_csv(d,header=None)

# %%
import numpy as np
druglist=[]
mismatch=[]
for j in range(2524):
    druglist.insert(j,D.loc[j][0])
for i in range(548):
    if not DF.loc[i][1] in (druglist):
            print(i,DF.loc[i][1])
            mismatch.insert(i,DF.loc[i][1])
            DF=DF.drop([i])
            drug=drug.drop([i],axis=0)
            drug=drug.drop([i],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-79a6947426f9> in <module>
#       3 mismatch=[]
#       4 for j in range(2524):
# ----> 5     druglist.insert(j,D.loc[j][0])
#       6 for i in range(548):
#       7     if not DF.loc[i][1] in (druglist):
#
# NameError: name 'D' is not defined

# %%
DF
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8d962b2673f1> in <module>
# ----> 1 DF
#
# NameError: name 'DF' is not defined

# %%
drug
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3a8072dae19a> in <module>
# ----> 1 drug
#
# NameError: name 'drug' is not defined

# %%
D
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-39e0574a4abf> in <module>
# ----> 1 D
#
# NameError: name 'D' is not defined

# %%
DF.to_csv("saved DF.csv",index=False)
DF = pd.read_csv("saved DF.csv", header=0)
drug.to_csv('saved drug.csv',index=False)
drug = pd.read_csv('saved drug.csv', header=0)

# %%
finalmatrix=[]
for i in range(533):
    for j in range(533):
        result=[DF.loc[i][1],DF.loc[j][1],drug.loc[i][j]]
        print(result)
        finalmatrix.append(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1ff810888c39> in <module>
#       2 for i in range(533):
#       3     for j in range(533):
# ----> 4         result=[DF.loc[i][1],DF.loc[j][1],drug.loc[i][j]]
#       5         print(result)
#       6         finalmatrix.append(result)
#
# NameError: name 'DF' is not defined

# %%
F=pd.DataFrame(finalmatrix)

# %%
F
# Out:
#               0        1  2
# 0       DB00945  DB00945  0
# 1       DB00945  DB00526  1
# 2       DB00945  DB00458  1
# 3       DB00945  DB00996  1
# 4       DB00945  DB00454  1
# ...         ...      ... ..
# 284084  DB00273  DB01216  1
# 284085  DB00273  DB00501  1
# 284086  DB00273  DB00433  1
# 284087  DB00273  DB01194  0
# 284088  DB00273  DB00273  0
#
# [284089 rows x 3 columns]

# %%
for K in range(1,301):
    F[K+2]=F[1].map(D.set_index(0)[k])
    K=K+1

# %%
F
# Out:
#             0        1    2             3             4             5    \
# 0       DB00945  DB00945    0     0.5972927     0.5972927     0.5972927
# 1       DB00945  DB00526    1     0.3996144     0.3996144     0.3996144
# 2       DB00945  DB00458    1    0.06341224    0.06341224    0.06341224
# 3       DB00945  DB00996    1  -0.005955442  -0.005955442  -0.005955442
# 4       DB00945  DB00454    1    0.37680155    0.37680155    0.37680155
# ...         ...      ...  ...           ...           ...           ...
# 284084  DB00273  DB01216    1    -0.7588995    -0.7588995    -0.7588995
# 284085  DB00273  DB00501    1    0.30188853    0.30188853    0.30188853
# 284086  DB00273  DB00433    1   -0.10464293   -0.10464293   -0.10464293
# 284087  DB00273  DB01194    0      -1.10635      -1.10635      -1.10635
# 284088  DB00273  DB00273    0     0.4977038     0.4977038     0.4977038
#
#                  6             7             8             9    ...  \
# 0          0.5972927     0.5972927     0.5972927     0.5972927  ...
# 1          0.3996144     0.3996144     0.3996144     0.3996144  ...
# 2         0.06341224    0.06341224    0.06341224    0.06341224  ...
# 3       -0.005955442  -0.005955442  -0.005955442  -0.005955442  ...
# 4         0.37680155    0.37680155    0.37680155    0.37680155  ...
# ...              ...           ...           ...           ...  ...
# 284084    -0.7588995    -0.7588995    -0.7588995    -0.7588995  ...
# 284085    0.30188853    0.30188853    0.30188853    0.30188853  ...
# 284086   -0.10464293   -0.10464293   -0.10464293   -0.10464293  ...
# 284087      -1.10635      -1.10635      -1.10635      -1.10635  ...
# 284088     0.4977038     0.4977038     0.4977038     0.4977038  ...
#
#                  293           294           295           296           297  \
# 0          0.5972927     0.5972927     0.5972927     0.5972927     0.5972927
# 1          0.3996144     0.3996144     0.3996144     0.3996144     0.3996144
# 2         0.06341224    0.06341224    0.06341224    0.06341224    0.06341224
# 3       -0.005955442  -0.005955442  -0.005955442  -0.005955442  -0.005955442
# 4         0.37680155    0.37680155    0.37680155    0.37680155    0.37680155
# ...              ...           ...           ...           ...           ...
# 284084    -0.7588995    -0.7588995    -0.7588995    -0.7588995    -0.7588995
# 284085    0.30188853    0.30188853    0.30188853    0.30188853    0.30188853
# 284086   -0.10464293   -0.10464293   -0.10464293   -0.10464293   -0.10464293
# 284087      -1.10635      -1.10635      -1.10635      -1.10635      -1.10635
# 284088     0.4977038     0.4977038     0.4977038     0.4977038     0.4977038
#
#                  298           299           300           301           302
# 0          0.5972927     0.5972927     0.5972927     0.5972927     0.5972927
# 1          0.3996144     0.3996144     0.3996144     0.3996144     0.3996144
# 2         0.06341224    0.06341224    0.06341224    0.06341224    0.06341224
# 3       -0.005955442  -0.005955442  -0.005955442  -0.005955442  -0.005955442
# 4         0.37680155    0.37680155    0.37680155    0.37680155    0.37680155
# ...              ...           ...           ...           ...           ...
# 284084    -0.7588995    -0.7588995    -0.7588995    -0.7588995    -0.7588995
# 284085    0.30188853    0.30188853    0.30188853    0.30188853    0.30188853
# 284086   -0.10464293   -0.10464293   -0.10464293   -0.10464293   -0.10464293
# 284087      -1.10635      -1.10635      -1.10635      -1.10635      -1.10635
# 284088     0.4977038     0.4977038     0.4977038     0.4977038     0.4977038
#
# [284089 rows x 303 columns]

# %%
F.to_csv("saved F.csv",index=False)
F=pd.read_csv('saved F.csv',header=0)

# %%
for i in range(304):
    for j in range(303):
        if i==j:
            F.drop([i])
            F.to_csv('saved F.csv',index=False)

# %%
F
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-1d01d0e6857d> in <module>
# ----> 1 F.to_csv('saved F.csv',index=False)
#
# c:\program files\python36\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# c:\program files\python36\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     200                 self.writer = UnicodeWriter(f, **writer_kwargs)
#     201
# --> 202             self._save()
#     203
#     204         finally:
#
# c:\program files\python36\lib\site-packages\pandas\io\formats\csvs.py in _save(self)
#     322                 break
#     323
# --> 324             self._save_chunk(start_i, end_i)
#     325
#     326     def _save_chunk(self, start_i, end_i):
#
# c:\program files\python36\lib\site-packages\pandas\io\formats\csvs.py in _save_chunk(self, start_i, end_i)
#     338                 decimal=self.decimal,
#     339                 date_format=self.date_format,
# --> 340                 quoting=self.quoting,
#     341             )
#     342
#
# c:\program files\python36\lib\site-packages\pandas\core\internals\blocks.py in to_native_types(self, slicer, na_rep, float_format, decimal, quoting, **kwargs)
#    2118                 values = np.array(values, dtype="object")
#    2119
# -> 2120             values[mask] = na_rep
#    2121             return values
#    2122
#
# KeyboardInterrupt:
